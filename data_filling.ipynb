# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split

from sklearn.ensemble import RandomForestRegressor

# %%
features = ['Timestamp', 'Average_OAT', 'Humidity', 'UV_Index', 'Average_Rainfall', 'NT_CoolingLoad', 'ST_CoolingLoad', 'CoolingLoad']
df = pd.read_csv("datasets/combine.csv", nrows = 86)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 2
#       1 features = ['Timestamp', 'Average_OAT', 'Humidity', 'UV_Index', 'Average_Rainfall', 'NT_CoolingLoad', 'ST_CoolingLoad', 'CoolingLoad']
# ----> 2 df = pd.read_csv("datasets/combine.csv", nrows = 86)
#       4 #df = pd.read_csv("datasets/extra_training_data.csv")
#       5 df
#
# ...

# %%
# read the empty column
fill = pd.read_csv("datasets/training_data.csv", skiprows = 4933, nrows = 38, names = features)

# %%
# define the input variable
train_input = df[['Average_OAT', 'Humidity', 'UV_Index', 'Average_Rainfall']]
train_output = df.CoolingLoad

fill_input = fill[['Average_OAT', 'Humidity', 'UV_Index', 'Average_Rainfall']]

# %%
# model training
model = RandomForestRegressor(n_estimators = 10000, max_features = 4)
model.fit(train_input, train_output)
# Out:
# RandomForestRegressor(max_features=4, n_estimators=10000)

# %%
# Using the model to fill data
predictions = model.predict(fill_input)
prediction = pd.DataFrame(predictions, columns=['predictions']).to_csv('prediction.csv')
pd.DataFrame(predictions)
# Out:
#               0
# 0   3134.212634
# 1   3075.216591
# 2   3164.287387
# 3   3227.526100
# 4   3169.132431
# 5   3083.266315
# 6   3193.232186
# 7   3210.443660
# 8   3135.811745
# 9   3152.727874
# 10  3142.914584
# 11  3154.629984
# 12  3154.629984
# 13  3132.177667
# 14  3087.587282
# 15  2971.945019
# 16  3131.308132
# 17  3134.246508
# 18  3139.780562
# 19  3128.114125
# 20  3235.056518
# 21  2815.996720
# 22  2971.655282
# 23  2884.761511
# 24  2904.946078
# 25  2957.185479
# 26  3087.644960
# 27  3112.111368
# 28  3308.425214
# 29  3894.891655
# 30  3537.388314
# 31  3395.110655
# 32  3406.898771
# 33  3506.835369
# 34  4741.827988
# 35  4821.198103
# 36  4849.373925
# 37  4751.903526
